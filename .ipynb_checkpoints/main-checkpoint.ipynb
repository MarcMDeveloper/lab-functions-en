# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
#your code here
def greater(a,b):
    if a < b:
        return b
    else:
        return a

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.040s
#
# OK

# %%
#your code here

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here
def greatest(new_list):
    max_digit = 0
    #return max(new_list)
    for number in new_list:
        if number > max_digit:
            max_digit = number

    return max_digit

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.042s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
#your code here
    sum_numbers = 0
    for number in lst:
        sum_numbers += number
    return sum_numbers

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.033s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
#your code here
    multiply = 1
    for number in lst:
        multiply *= number
    return multiply

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.043s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
#your code here
    if oper == "*":
        return mult_all(arr)

    return sum_all(arr)

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.032s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
#your code here
    result = 1
    for number in range(2, n + 1):
        result *= number
    return result

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.033s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
#your code here
    unique_values = [x for i, x in enumerate(lst_un) if x not in lst_un[:i]]
    return unique_values

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.115s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
#your code here
    choose_number = 0
    max_counter = 0
    length = len(arr)
    for index_element in range(0, length):
        counter = 0
        for index_number in range(index_element, length):
            if arr[index_element] == arr[index_number]:
                counter += 1
        if counter > max_counter:
            max_counter = counter
            choose_number = arr[index_element]
    return choose_number

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.081s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
#your code here
    length = 0
    count = 0
    for number in list_sd:
        length += 1 
        count += number
        
    mean = count / length

    # Calculate variance
    squared_diffs = 0
    for number in list_sd:
        diff = number - mean
        squared = diff * diff
        squared_diffs += squared
        
    variance = squared_diffs / (length-1)
    standard_deviation = variance ** 0.5

    return standard_deviation

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.034s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    alphabet = set ("abcdefghijklmnopqrstuvwxyz")
    string = string.lower()
    
    letters_in_string = {char for char in string if "a" <= char <= "z"}
   
    return letters_in_string == alphabet

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.009s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
#your code here
    words = []
    word = ""
    for char in string:
        if char == ',':
            words.append(word)
            word = ""
        else:
            word += char
    words.append(word)  
    
    sorted_words = sorted(words)
    
    result = ""
    for i, word in enumerate(sorted_words):
        if i > 0:
            result += ", "
        result += word
    
    return result

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'fliozcfqky, ghqcc, gmixvsl, hvwhvvkcl, imol, mkiptej[64 chars]koil' != 'fliozcfqky,ghqcc,gmixvsl,hvwhvvkcl,imol,mkiptej,nijd[52 chars]koil'
# - fliozcfqky, ghqcc, gmixvsl, hvwhvvkcl, imol, mkiptej, nijdbcvwn, snskksjm, tlkdcxhpyw, ughkvzm, wakxk, xldxbrfah, yikoil
# ?            -      -        -          -     -        -          -         -           -        -      -          -
# + fliozcfqky,ghqcc,gmixvsl,hvwhvvkcl,imol,mkiptej,nijdbcvwn,snskksjm,tlkdcxhpyw,ughkvzm,wakxk,xldxbrfah,yikoil
#  : Should be fliozcfqky,ghqcc,gmixvsl,hvwhvvkcl,imol,mkiptej,nijdbcvwn,snskksjm,tlkdcxhpyw,ughkvzm,wakxk,xldxbrfah,yikoil
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'fgrssxoir, fjfsyuoui, hbatfuwbkr, hghfqrrbsv, pkxip[44 chars]zogn' != 'fgrssxoir,fjfsyuoui,hbatfuwbkr,hghfqrrbsv,pkxip,sps[34 chars]zogn'
# - fgrssxoir, fjfsyuoui, hbatfuwbkr, hghfqrrbsv, pkxip, spsfhd, tndyigle, vskq, wbaqtld, xxdlcfo, zogn
# ?           -          -           -           -      -       -         -     -        -        -
# + fgrssxoir,fjfsyuoui,hbatfuwbkr,hghfqrrbsv,pkxip,spsfhd,tndyigle,vskq,wbaqtld,xxdlcfo,zogn
#  : Should be fgrssxoir,fjfsyuoui,hbatfuwbkr,hghfqrrbsv,pkxip,spsfhd,tndyigle,vskq,wbaqtld,xxdlcfo,zogn
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users
#  : Should be cyphlrauhg,czazyqrzz,dang,dufpkipbrm,lcbsjuxkgp,lnnujbzaqh,mgbwuszh,otftjw,oydaucabn,qlyoq,qqbktsvaig,sksrzfndqh,spfanjavma,spqmtdtysq,tksr,tmlghdpi,tstvecrs,vhfmtctox,wpzqqk,wzkfkdeizs
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'htkytwoeuq, lloupewhwu, qelrm, qlqbpkicwf, uchhpsleq, zyegmtk' != 'htkytwoeuq,lloupewhwu,qelrm,qlqbpkicwf,uchhpsleq,zyegmtk'
# - htkytwoeuq, lloupewhwu, qelrm, qlqbpkicwf, uchhpsleq, zyegmtk
# ?            -           -      -           -          -
# + htkytwoeuq,lloupewhwu,qelrm,qlqbpkicwf,uchhpsleq,zyegmtk
#  : Should be htkytwoeuq,lloupewhwu,qelrm,qlqbpkicwf,uchhpsleq,zyegmtk
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bfjphvz, iepl, jecvfj, jxdahzho, loiuafnw, ogkc, [73 chars]gqop' != 'bfjphvz,iepl,jecvfj,jxdahzho,loiuafnw,ogkc,rcjpmo[59 chars]gqop'
# - bfjphvz, iepl, jecvfj, jxdahzho, loiuafnw, ogkc, rcjpmoa, tenon, upomt, wbtsklpx, wgwmlzx, wlwcnncaw, ybkbjlsvm, ynnq, zuygqop
# ?         -     -       -         -         -     -        -      -      -         -        -          -          -     -
# + bfjphvz,iepl,jecvfj,jxdahzho,loiuafnw,ogkc,rcjpmoa,tenon,upomt,wbtsklpx,wgwmlzx,wlwcnncaw,ybkbjlsvm,ynnq,zuygqop
#  : Should be bfjphvz,iepl,jecvfj,jxdahzho,loiuafnw,ogkc,rcjpmoa,tenon,upomt,wbtsklpx,wgwmlzx,wlwcnncaw,ybkbjlsvm,ynnq,zuygqop
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bgexauf, blxic, bvqf, cipcclsli, cwjnzje, cxkfl, [133 chars]indi' != 'bgexauf,blxic,bvqf,cipcclsli,cwjnzje,cxkfl,czxomn[112 chars]indi'
# - bgexauf, blxic, bvqf, cipcclsli, cwjnzje, cxkfl, czxomncrd, dqshyeh, eszzdb, fcif, ipjsopo, iqqvqcb, jwlhbip, lfeisa, obarx, oojsfgyxgb, rcpkts, twpibpv, xjilooz, xwxmh, yklpi, zdmgnindi
# ?         -      -     -          -        -      -          -        -       -     -        -        -        -       -      -           -       -        -        -      -      -
# + bgexauf,blxic,bvqf,cipcclsli,cwjnzje,cxkfl,czxomncrd,dqshyeh,eszzdb,fcif,ipjsopo,iqqvqcb,jwlhbip,lfeisa,obarx,oojsfgyxgb,rcpkts,twpibpv,xjilooz,xwxmh,yklpi,zdmgnindi
#  : Should be bgexauf,blxic,bvqf,cipcclsli,cwjnzje,cxkfl,czxomncrd,dqshyeh,eszzdb,fcif,ipjsopo,iqqvqcb,jwlhbip,lfeisa,obarx,oojsfgyxgb,rcpkts,twpibpv,xjilooz,xwxmh,yklpi,zdmgnindi
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'jwbg, nzdnwvpfcn, qlixogjxmx, wrxyq, zowkg' != 'jwbg,nzdnwvpfcn,qlixogjxmx,wrxyq,zowkg'
# - jwbg, nzdnwvpfcn, qlixogjxmx, wrxyq, zowkg
# ?      -           -           -      -
# + jwbg,nzdnwvpfcn,qlixogjxmx,wrxyq,zowkg
#  : Should be jwbg,nzdnwvpfcn,qlixogjxmx,wrxyq,zowkg
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'dvjnt, epbrri, fcky, gjhb, gphpq, hnzd, jppspio[66 chars]aglo' != 'dvjnt,epbrri,fcky,gjhb,gphpq,hnzd,jppspiogi,lmp[52 chars]aglo'
# - dvjnt, epbrri, fcky, gjhb, gphpq, hnzd, jppspiogi, lmpktv, lodvicyk, tjogo, ugdaeh, xaplrubz, xhdrt, zmjt, zmlxzbaglo
# ?       -       -     -     -      -     -          -       -         -      -       -         -      -     -
# + dvjnt,epbrri,fcky,gjhb,gphpq,hnzd,jppspiogi,lmpktv,lodvicyk,tjogo,ugdaeh,xaplrubz,xhdrt,zmjt,zmlxzbaglo
#  : Should be dvjnt,epbrri,fcky,gjhb,gphpq,hnzd,jppspiogi,lmpktv,lodvicyk,tjogo,ugdaeh,xaplrubz,xhdrt,zmjt,zmlxzbaglo
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bcjulmcggd, dywuokmsn, gxalrr, jtzhj, kvbmf, mybek, [60 chars]ztbe' != 'bcjulmcggd,dywuokmsn,gxalrr,jtzhj,kvbmf,mybek,ptuwv,[46 chars]ztbe'
# - bcjulmcggd, dywuokmsn, gxalrr, jtzhj, kvbmf, mybek, ptuwv, qbzoyuh, qgcrgxi, tkbprkuu, ucck, vbmg, vlpe, xieei, ztbe
# ?            -          -       -      -      -      -      -        -        -         -     -     -     -      -
# + bcjulmcggd,dywuokmsn,gxalrr,jtzhj,kvbmf,mybek,ptuwv,qbzoyuh,qgcrgxi,tkbprkuu,ucck,vbmg,vlpe,xieei,ztbe
#  : Should be bcjulmcggd,dywuokmsn,gxalrr,jtzhj,kvbmf,mybek,ptuwv,qbzoyuh,qgcrgxi,tkbprkuu,ucck,vbmg,vlpe,xieei,ztbe
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'eyua, fbbunq, fenzld, fmogh, fvsdkqm, glair, h[119 chars]qynl' != 'eyua,fbbunq,fenzld,fmogh,fvsdkqm,glair,hmdzrxi[101 chars]qynl'
# - eyua, fbbunq, fenzld, fmogh, fvsdkqm, glair, hmdzrxid, hvzsicoms, igryzkeor, knionjhkc, mxgcxpni, nwkgjmqw, nztftwbp, orngbpfb, tjfxopyy, uueu, vmfgogq, ylvvb, zjhmmqynl
# ?      -       -       -      -        -      -         -          -          -          -         -         -         -         -         -     -        -      -
# + eyua,fbbunq,fenzld,fmogh,fvsdkqm,glair,hmdzrxid,hvzsicoms,igryzkeor,knionjhkc,mxgcxpni,nwkgjmqw,nztftwbp,orngbpfb,tjfxopyy,uueu,vmfgogq,ylvvb,zjhmmqynl
#  : Should be eyua,fbbunq,fenzld,fmogh,fvsdkqm,glair,hmdzrxid,hvzsicoms,igryzkeor,knionjhkc,mxgcxpni,nwkgjmqw,nztftwbp,orngbpfb,tjfxopyy,uueu,vmfgogq,ylvvb,zjhmmqynl
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bawthk, bjutkj, codbhmykwc, hkbm, jjpapl, lkmzbp[40 chars]bpry' != 'bawthk,bjutkj,codbhmykwc,hkbm,jjpapl,lkmzbpxz,oj[31 chars]bpry'
# - bawthk, bjutkj, codbhmykwc, hkbm, jjpapl, lkmzbpxz, ojmmbzdw, pfvcgmzwx, rcdzqsan, velcnbpry
# ?        -       -           -     -       -         -         -          -         -
# + bawthk,bjutkj,codbhmykwc,hkbm,jjpapl,lkmzbpxz,ojmmbzdw,pfvcgmzwx,rcdzqsan,velcnbpry
#  : Should be bawthk,bjutkj,codbhmykwc,hkbm,jjpapl,lkmzbpxz,ojmmbzdw,pfvcgmzwx,rcdzqsan,velcnbpry
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'dqellxzg, inuf, rxufeva, skazwaklj, twmnxjhu, xunyxctsh' != 'dqellxzg,inuf,rxufeva,skazwaklj,twmnxjhu,xunyxctsh'
# - dqellxzg, inuf, rxufeva, skazwaklj, twmnxjhu, xunyxctsh
# ?          -     -        -          -         -
# + dqellxzg,inuf,rxufeva,skazwaklj,twmnxjhu,xunyxctsh
#  : Should be dqellxzg,inuf,rxufeva,skazwaklj,twmnxjhu,xunyxctsh
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'aftekxin, apayzl, auoiguzfiq, bgsmdap, bwzx, bxgjg[101 chars]flwz' != 'aftekxin,apayzl,auoiguzfiq,bgsmdap,bwzx,bxgjgc,cry[86 chars]flwz'
# - aftekxin, apayzl, auoiguzfiq, bgsmdap, bwzx, bxgjgc, cryipezbq, eematrsgs, huuappskzy, jtzczrr, nqukst, ppzmtxq, sosxkn, tbwvacypka, urgcoyjifv, vonfewflwz
# ?          -       -           -        -     -       -          -          -           -        -       -        -       -           -           -
# + aftekxin,apayzl,auoiguzfiq,bgsmdap,bwzx,bxgjgc,cryipezbq,eematrsgs,huuappskzy,jtzczrr,nqukst,ppzmtxq,sosxkn,tbwvacypka,urgcoyjifv,vonfewflwz
#  : Should be aftekxin,apayzl,auoiguzfiq,bgsmdap,bwzx,bxgjgc,cryipezbq,eematrsgs,huuappskzy,jtzczrr,nqukst,ppzmtxq,sosxkn,tbwvacypka,urgcoyjifv,vonfewflwz
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'elioujynvi, fape, gaamchdupm, gncxjqw, iakfet, ihetp[49 chars]yedm' != 'elioujynvi,fape,gaamchdupm,gncxjqw,iakfet,ihetpiufug[38 chars]yedm'
# - elioujynvi, fape, gaamchdupm, gncxjqw, iakfet, ihetpiufug, imqp, kmkcllqkm, pfjpk, prgyugg, toasrrl, yedm
# ?            -     -           -        -       -           -     -          -      -        -        -
# + elioujynvi,fape,gaamchdupm,gncxjqw,iakfet,ihetpiufug,imqp,kmkcllqkm,pfjpk,prgyugg,toasrrl,yedm
#  : Should be elioujynvi,fape,gaamchdupm,gncxjqw,iakfet,ihetpiufug,imqp,kmkcllqkm,pfjpk,prgyugg,toasrrl,yedm
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bmaahwjl, dsehvpnowy, fnsncrgw, foisoiyhv, hkbhstk[108 chars]cvgz' != 'bmaahwjl,dsehvpnowy,fnsncrgw,foisoiyhv,hkbhstkxq,i[92 chars]cvgz'
# - bmaahwjl, dsehvpnowy, fnsncrgw, foisoiyhv, hkbhstkxq, inxm, mtrmjihizl, nlatrxtdxs, obnemblik, pevbfor, rmuybnk, snxjtm, wdfgfae, ybapuuxo, yimtns, yjwqcuv, zcvgz
# ?          -           -         -          -          -     -           -           -          -        -        -       -        -         -       -        -
# + bmaahwjl,dsehvpnowy,fnsncrgw,foisoiyhv,hkbhstkxq,inxm,mtrmjihizl,nlatrxtdxs,obnemblik,pevbfor,rmuybnk,snxjtm,wdfgfae,ybapuuxo,yimtns,yjwqcuv,zcvgz
#  : Should be bmaahwjl,dsehvpnowy,fnsncrgw,foisoiyhv,hkbhstkxq,inxm,mtrmjihizl,nlatrxtdxs,obnemblik,pevbfor,rmuybnk,snxjtm,wdfgfae,ybapuuxo,yimtns,yjwqcuv,zcvgz
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'cimganqad, ejrmn, hmlca, llgswyskze, lxccrm, nqxl, waalhpcas, ykyqmlod' != 'cimganqad,ejrmn,hmlca,llgswyskze,lxccrm,nqxl,waalhpcas,ykyqmlod'
# - cimganqad, ejrmn, hmlca, llgswyskze, lxccrm, nqxl, waalhpcas, ykyqmlod
# ?           -      -      -           -       -     -          -
# + cimganqad,ejrmn,hmlca,llgswyskze,lxccrm,nqxl,waalhpcas,ykyqmlod
#  : Should be cimganqad,ejrmn,hmlca,llgswyskze,lxccrm,nqxl,waalhpcas,ykyqmlod
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bholwlz, btajxs, jmqdjbpjvo, nymxawg, olrykvnuv, tjqfpuahpx' != 'bholwlz,btajxs,jmqdjbpjvo,nymxawg,olrykvnuv,tjqfpuahpx'
# - bholwlz, btajxs, jmqdjbpjvo, nymxawg, olrykvnuv, tjqfpuahpx
# ?         -       -           -        -          -
# + bholwlz,btajxs,jmqdjbpjvo,nymxawg,olrykvnuv,tjqfpuahpx
#  : Should be bholwlz,btajxs,jmqdjbpjvo,nymxawg,olrykvnuv,tjqfpuahpx
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users
# + aeepf,ageqi,bldrwlc,bsuisi,cqskyekfam,cseg,dcdvfnka,eryrz,ginphd,gzncff,hpcqpkrui,hvmf,ktbg,lseteduzw,pmcllfgh,qqujwxcdo,skvv,sqyfam,umvlsikkqw,unsmf,zhynnmmt,zxijuop
#  : Should be aeepf,ageqi,bldrwlc,bsuisi,cqskyekfam,cseg,dcdvfnka,eryrz,ginphd,gzncff,hpcqpkrui,hvmf,ktbg,lseteduzw,pmcllfgh,qqujwxcdo,skvv,sqyfam,umvlsikkqw,unsmf,zhynnmmt,zxijuop
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bgwjg, bjxvyizpud, iedvoppe, jkfo, lmfna, yqzuxldeyg' != 'bgwjg,bjxvyizpud,iedvoppe,jkfo,lmfna,yqzuxldeyg'
# - bgwjg, bjxvyizpud, iedvoppe, jkfo, lmfna, yqzuxldeyg
# ?       -           -         -     -      -
# + bgwjg,bjxvyizpud,iedvoppe,jkfo,lmfna,yqzuxldeyg
#  : Should be bgwjg,bjxvyizpud,iedvoppe,jkfo,lmfna,yqzuxldeyg
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'dcuu, dfywuhgne, eelrjowg, faabdnagtx, fgwlzae[122 chars]raqb' != 'dcuu,dfywuhgne,eelrjowg,faabdnagtx,fgwlzaengw,[104 chars]raqb'
# - dcuu, dfywuhgne, eelrjowg, faabdnagtx, fgwlzaengw, gboh, gdnmnlf, ibecgoxfw, jivlt, jsvki, maxu, oxujzfifi, pishtg, rxtlx, trchpo, twftahjml, velcprhwf, wvfmqabt, zznxpraqb
# ?      -          -         -           -           -     -        -          -      -      -     -          -       -      -       -          -          -         -
# + dcuu,dfywuhgne,eelrjowg,faabdnagtx,fgwlzaengw,gboh,gdnmnlf,ibecgoxfw,jivlt,jsvki,maxu,oxujzfifi,pishtg,rxtlx,trchpo,twftahjml,velcprhwf,wvfmqabt,zznxpraqb
#  : Should be dcuu,dfywuhgne,eelrjowg,faabdnagtx,fgwlzaengw,gboh,gdnmnlf,ibecgoxfw,jivlt,jsvki,maxu,oxujzfifi,pishtg,rxtlx,trchpo,twftahjml,velcprhwf,wvfmqabt,zznxpraqb
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'brgxw, cospm, dwwpqir, elmcrtaieo, ibdlaq, ixwc[95 chars]ikxq' != 'brgxw,cospm,dwwpqir,elmcrtaieo,ibdlaq,ixwcojf,j[80 chars]ikxq'
# - brgxw, cospm, dwwpqir, elmcrtaieo, ibdlaq, ixwcojf, juulidvub, lbcyjv, nexx, rchbzdju, rhmeobxlec, ubqdo, wmufatotbn, wuhqnchbs, yrnlsybxu, yvikxq
# ?       -      -        -           -       -        -          -       -     -         -           -      -           -          -          -
# + brgxw,cospm,dwwpqir,elmcrtaieo,ibdlaq,ixwcojf,juulidvub,lbcyjv,nexx,rchbzdju,rhmeobxlec,ubqdo,wmufatotbn,wuhqnchbs,yrnlsybxu,yvikxq
#  : Should be brgxw,cospm,dwwpqir,elmcrtaieo,ibdlaq,ixwcojf,juulidvub,lbcyjv,nexx,rchbzdju,rhmeobxlec,ubqdo,wmufatotbn,wuhqnchbs,yrnlsybxu,yvikxq
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'aasz, avvtuzz, bvfgb, cgrpujn, ljiy, mfmhjtam,[56 chars]cbuo' != 'aasz,avvtuzz,bvfgb,cgrpujn,ljiy,mfmhjtam,pvyfn[44 chars]cbuo'
# - aasz, avvtuzz, bvfgb, cgrpujn, ljiy, mfmhjtam, pvyfngnml, tgnrxacupu, unbd, xkatlp, xmfbvje, xyrsa, ywcbuo
# ?      -        -      -        -     -         -          -           -     -       -        -      -
# + aasz,avvtuzz,bvfgb,cgrpujn,ljiy,mfmhjtam,pvyfngnml,tgnrxacupu,unbd,xkatlp,xmfbvje,xyrsa,ywcbuo
#  : Should be aasz,avvtuzz,bvfgb,cgrpujn,ljiy,mfmhjtam,pvyfngnml,tgnrxacupu,unbd,xkatlp,xmfbvje,xyrsa,ywcbuo
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'ehfpjaeq, luijt, oyssemwlj, poaalxtja, rxhzr, twzfmkmbvy' != 'ehfpjaeq,luijt,oyssemwlj,poaalxtja,rxhzr,twzfmkmbvy'
# - ehfpjaeq, luijt, oyssemwlj, poaalxtja, rxhzr, twzfmkmbvy
# ?          -      -          -          -      -
# + ehfpjaeq,luijt,oyssemwlj,poaalxtja,rxhzr,twzfmkmbvy
#  : Should be ehfpjaeq,luijt,oyssemwlj,poaalxtja,rxhzr,twzfmkmbvy
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'eblslxunc, efjdcyy, etlrangbti, gpgmoz, hxqqrjsjbn,[70 chars]uzim' != 'eblslxunc,efjdcyy,etlrangbti,gpgmoz,hxqqrjsjbn,itzp[57 chars]uzim'
# - eblslxunc, efjdcyy, etlrangbti, gpgmoz, hxqqrjsjbn, itzprah, ixtsft, lifor, nbyqrfz, otijcrcq, qixl, qlzdyi, tnljtvonvo, uzim
# ?           -        -           -       -           -        -       -      -        -         -     -       -           -
# + eblslxunc,efjdcyy,etlrangbti,gpgmoz,hxqqrjsjbn,itzprah,ixtsft,lifor,nbyqrfz,otijcrcq,qixl,qlzdyi,tnljtvonvo,uzim
#  : Should be eblslxunc,efjdcyy,etlrangbti,gpgmoz,hxqqrjsjbn,itzprah,ixtsft,lifor,nbyqrfz,otijcrcq,qixl,qlzdyi,tnljtvonvo,uzim
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'lyln, nrofrouc, ohruxszzix, qlugvfzn, qppn, slgdkaxcmt, xlonldru, yjpnpz' != 'lyln,nrofrouc,ohruxszzix,qlugvfzn,qppn,slgdkaxcmt,xlonldru,yjpnpz'
# - lyln, nrofrouc, ohruxszzix, qlugvfzn, qppn, slgdkaxcmt, xlonldru, yjpnpz
# ?      -         -           -         -     -           -         -
# + lyln,nrofrouc,ohruxszzix,qlugvfzn,qppn,slgdkaxcmt,xlonldru,yjpnpz
#  : Should be lyln,nrofrouc,ohruxszzix,qlugvfzn,qppn,slgdkaxcmt,xlonldru,yjpnpz
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users
mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bdljou, cpzvcxjgzp, dbillze, doaq, ecyvtx, evdg,[134 chars]zfmj' != 'bdljou,cpzvcxjgzp,dbillze,doaq,ecyvtx,evdg,fsnsv[114 chars]zfmj'
# - bdljou, cpzvcxjgzp, dbillze, doaq, ecyvtx, evdg, fsnsvoxl, fxzbld, gwrajnqnam, iotv, jmriaois, kawnro, krgwayuxoa, lqqiyga, navupvsl, norvve, oguxo, uaonk, uxqkookvrl, wbjqjncwfr, xjzfmj
# ?        -           -        -     -       -     -         -       -           -     -         -       -           -        -         -       -      -      -           -           -
# + bdljou,cpzvcxjgzp,dbillze,doaq,ecyvtx,evdg,fsnsvoxl,fxzbld,gwrajnqnam,iotv,jmriaois,kawnro,krgwayuxoa,lqqiyga,navupvsl,norvve,oguxo,uaonk,uxqkookvrl,wbjqjncwfr,xjzfmj
#  : Should be bdljou,cpzvcxjgzp,dbillze,doaq,ecyvtx,evdg,fsnsvoxl,fxzbld,gwrajnqnam,iotv,jmriaois,kawnro,krgwayuxoa,lqqiyga,navupvsl,norvve,oguxo,uaonk,uxqkookvrl,wbjqjncwfr,xjzfmj
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'dnxdojdgzp, izccf, kcnr, oirpnjle, omhe, qrydtgadv' != 'dnxdojdgzp,izccf,kcnr,oirpnjle,omhe,qrydtgadv'
# - dnxdojdgzp, izccf, kcnr, oirpnjle, omhe, qrydtgadv
# ?            -      -     -         -     -
# + dnxdojdgzp,izccf,kcnr,oirpnjle,omhe,qrydtgadv
#  : Should be dnxdojdgzp,izccf,kcnr,oirpnjle,omhe,qrydtgadv
#
# ======================================================================
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 'bgvfzahl, bwmj, chxx, cibs, diybacmr, dxryxqdyh, e[110 chars]xdbq' != 'bgvfzahl,bwmj,chxx,cibs,diybacmr,dxryxqdyh,eosmfvp[93 chars]xdbq'
# - bgvfzahl, bwmj, chxx, cibs, diybacmr, dxryxqdyh, eosmfvpnsh, fqoloh, hcin, ohpbkoenzn, toqosusx, ubvm, ugqalqay, umehrttiam, wemugm, wkfzoelt, wlodgjsjat, zbuocxdbq
# ?          -     -     -     -         -          -           -       -     -           -         -     -         -           -       -         -           -
# + bgvfzahl,bwmj,chxx,cibs,diybacmr,dxryxqdyh,eosmfvpnsh,fqoloh,hcin,ohpbkoenzn,toqosusx,ubvm,ugqalqay,umehrttiam,wemugm,wkfzoelt,wlodgjsjat,zbuocxdbq
#  : Should be bgvfzahl,bwmj,chxx,cibs,diybacmr,dxryxqdyh,eosmfvpnsh,fqoloh,hcin,ohpbkoenzn,toqosusx,ubvm,ugqalqay,umehrttiam,wemugm,wkfzoelt,wlodgjsjat,zbuocxdbq
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.190s
#
# FAILED (failures=100)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
    if len(password) < 8:
        return False
        
    has_lower = False
    has_upercase = False
    has_number = False
    has_special_character = False
    special_characters = "!@#$%^&*(),.?\":{}|<>"
    
    for character in password:
        if character.islower():
            has_lower = True
        elif character.isupper():
            has_uppercase = True
        elif character.isdigit():
            has_number = True
        elif character in special_characters:
            has_special_character = True
                
    return (has_lower and has_upercase and has_number and has_special_character)

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# FF.F.F...F......F.....FF......F.....F.......F..F......F.F.F.FFFF..F...FF.F.F......FF..F..F...F.....F
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\Bootcamp\Work\Week_2\Lab Functions\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: True != False : Should be False
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.041s
#
# FAILED (failures=30)
